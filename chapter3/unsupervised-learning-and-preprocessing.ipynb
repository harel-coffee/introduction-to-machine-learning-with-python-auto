# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import sklearn
import mglearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib notebook
# Out:
# /Users/fengp/anaconda3/lib/python3.6/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /Users/fengp/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Types of Unsupervised Learning

# %% [markdown]
# 1. Unsupervised transformation
#    1. Dimensionality Reduction
# 11. Clustering Algorithm

# %% [markdown]
# # Challenge of Unsupervised Learning

# %% [markdown]
# ## Preprocessing and scaling

# %%
mglearn.plots.plot_scaling()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
cancer = sklearn.datasets.load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((426, 30), (143, 30), (426,), (143,))

# %%
scaler = sklearn.preprocessing.MinMaxScaler()
X_train_trans = scaler.fit_transform(X_train)
DataFrame(X_train).describe()
# Out:
#                0           1           2            3           4   \
# count  426.000000  426.000000  426.000000   426.000000  426.000000
# mean    14.107486   19.237418   91.842019   653.582394    0.096257
# std      3.557242    4.255037   24.530174   354.139667    0.013630
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.662500   16.172500   74.902500   416.450000    0.086825
# 50%     13.280000   18.700000   86.040000   544.050000    0.096530
# 75%     15.825000   21.765000  104.025000   780.400000    0.104900
# max     27.420000   33.810000  186.900000  2501.000000    0.142500
#
#                5           6           7           8           9   ...  \
# count  426.000000  426.000000  426.000000  426.000000  426.000000  ...
# mean     0.104215    0.087714    0.048768    0.181487    0.062843  ...
# std      0.053085    0.078827    0.039218    0.027140    0.006911  ...
# min      0.019380    0.000000    0.000000    0.106000    0.050250  ...
# ...

# %%
DataFrame(X_train_trans).describe()
# Out:
#                0           1           2           3           4           5   \
# count  426.000000  426.000000  426.000000  426.000000  426.000000  426.000000
# mean     0.348671    0.395329    0.335770    0.216366    0.485446    0.260214
# std      0.174042    0.176558    0.171408    0.150218    0.151662    0.162828
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.229047    0.268154    0.217403    0.115779    0.380494    0.143273
# 50%      0.308185    0.373029    0.295227    0.169905    0.488483    0.223453
# 75%      0.432702    0.500207    0.420900    0.270159    0.581618    0.335547
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9   ...          20  \
# count  426.000000  426.000000  426.000000  426.000000  ...  426.000000
# mean     0.233655    0.254931    0.381248    0.266862  ...    0.294946
# ...

# %%
X_test_trans = scaler.transform(X_test)

# %%
svc = sklearn.svm.SVC()
svc.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.90209790209790208

# %%
svc.fit(X_train_trans, y_train).score(X_test_trans, y_test)
# Out:
# 0.97902097902097907

# %%
scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(X_train)
X_train_trans = scaler.transform(X_train)
X_test_trans = scaler.transform(X_test)
svc.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.90209790209790208

# %%
svc.fit(X_train_trans, y_train).score(X_test_trans, y_test)
# Out:
# 0.97902097902097907

# %%
DataFrame(X_train_trans).describe()
# Out:
#                  0             1             2             3             4   \
# count  4.260000e+02  4.260000e+02  4.260000e+02  4.260000e+02  4.260000e+02
# mean  -1.671589e-15  4.268886e-16 -5.506810e-16  3.904024e-16 -6.549273e-16
# std    1.001176e+00  1.001176e+00  1.001176e+00  1.001176e+00  1.001176e+00
# min   -2.005729e+00 -2.241725e+00 -1.961198e+00 -1.442036e+00 -3.204605e+00
# 25%   -6.881344e-01 -7.211504e-01 -6.913704e-01 -6.703886e-01 -6.928264e-01
# 50%   -2.328936e-01 -1.264501e-01 -2.368039e-01 -3.096552e-01  2.004999e-02
# 75%    4.833895e-01  5.947197e-01  4.972368e-01  3.585216e-01  6.348646e-01
# max    3.746770e+00  3.428811e+00  3.879701e+00  5.222769e+00  3.396756e+00
#
#                  5             6             7             8             9   \
# count  4.260000e+02  4.260000e+02  4.260000e+02  4.260000e+02  4.260000e+02
# mean  -8.097331e-16 -1.261380e-16 -9.588053e-16  4.786208e-16 -2.517157e-15
# ...
